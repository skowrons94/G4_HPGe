# %%
import ROOT

import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

from glob import glob
from tqdm import tqdm
# Out:
# Welcome to JupyROOT 6.28/04

# %%
a = 3.78288e-03
b = 6.57475e-04
c = 1.54547e-08

MevToKev = 1e3

def get_reso( energy ):
    return np.sqrt( a + b * energy + c * energy**2 )

# %%
for file in glob("data/*.root"):

    name = file.split( "/" )[1][:-5]
    events = { "Energy" : [] }

    try:
        f1 = ROOT.TFile( file )
    except:
        print( "Error opening file: {}".format( file ) )
        continue

    t1 = f1.Get( "t1" )

    for idx in tqdm( range( t1.GetEntries( ) ) ):

        t1.GetEntry( idx )

        energy = getattr( t1, "Energy" ) * MevToKev

        if( energy > 0 ): energy = np.random.normal( energy, get_reso( energy ) )

        events["Energy"].append( energy )

    df = pd.DataFrame( events )
    df.to_pickle( "processed/{}.pkl".format(name) )
# Out:
# 100%|██████████| 1000000/1000000 [00:01<00:00, 591003.59it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 603953.72it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 642346.95it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 605853.18it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 610629.22it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 632897.77it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 616812.59it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 617598.94it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 624751.94it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 635417.33it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 659177.98it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 631986.19it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 637272.22it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 612182.48it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 648768.41it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 656336.92it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 615754.75it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 613209.15it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 619361.91it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 634756.11it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 584421.38it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 641604.30it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 622263.18it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 616584.00it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 616385.65it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 631660.40it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 654060.77it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 613197.14it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 616918.01it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 613895.75it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 653555.06it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 619108.49it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 626464.43it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 599938.69it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 642085.58it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 579077.25it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 589107.08it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 608546.69it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 618099.33it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 608852.43it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 612828.82it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 601091.92it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 577373.61it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 615635.81it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 664179.58it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 625529.01it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 619526.95it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 626399.59it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 625771.66it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 621566.31it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 607984.78it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 631084.07it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 608134.55it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 619231.61it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 620972.48it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 618939.02it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 639488.89it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 634696.56it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 619443.23it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 639883.61it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 620330.43it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 610585.21it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 620502.96it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 630200.33it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 653658.45it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 625413.91it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 609083.19it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 608154.13it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 612296.70it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 613780.85it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 654683.32it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 653147.26it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 652924.39it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 621416.76it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 630551.64it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 651873.39it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 622568.54it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 630364.00it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 610359.44it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 629382.91it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 612727.48it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 631287.62it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 615121.90it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 603822.70it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 615888.66it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 590360.31it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 620116.55it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 657381.86it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 616311.56it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 618212.39it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 638519.45it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 623005.20it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 608914.30it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 647560.54it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 652277.38it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 616100.08it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 598729.20it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 630282.91it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 609833.54it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 623698.81it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 623918.69it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 615914.89it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 601249.43it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 609009.70it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 602901.19it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 646035.39it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 620871.56it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 647361.34it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 603446.45it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 610311.66it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 630311.14it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 601282.10it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 607038.59it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 604338.01it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 604312.50it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 608126.00it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 653037.74it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 645819.93it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 618749.56it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 660153.64it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 649082.16it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 625055.08it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00, 615965.27it/s]
# 100%|██████████| 1000000/1000000 [00:01<00:00,